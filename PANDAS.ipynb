# %% [markdown]
# <a href="https://colab.research.google.com/github/eshu077/Complete_Machine_Learning/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
lst =[1,2,3,4,5]
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
# SERIES

# %%
# prompt: correct it -
# pd.series(lst)

pd.Series(lst)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser = pd.Series([5,6,2,37,89,1])
ser
# Out:
# 0     5
# 1     6
# 2     2
# 3    37
# 4    89
# 5     1
# dtype: int64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser = pd.Series([5,6,2,37,89,1], index=['a','b','c','d','e','f'],name = 'Ratings')
ser
# Out:
# a     5
# b     6
# c     2
# d    37
# e    89
# f     1
# Name: Ratings, dtype: int64

# %%
# DATAFRAME

# %%
lst=[['apple',5],['mango',4],['banana',6]]
lst
# Out:
# [['apple', 5], ['mango', 4], ['banana', 6]]

# %%
# prompt: df = pd.dataframe(lst) correct it

df = pd.DataFrame(lst)
df
# Out:
#         0  1
# 0   apple  5
# 1   mango  4
# 2  banana  6

# %%
df = pd.DataFrame(lst, columns=['fruits','quantity'])
df
# Out:
#    fruits  quantity
# 0   apple         5
# 1   mango         4
# 2  banana         6

# %%
lst=[['apple',5,'l'],['mango',4,'d'],['banana',6,'l'],['orange',8,'d']]
df = pd.DataFrame(lst, columns=['fruits','quantity','Like/Dislike'])
df
# Out:
#    fruits  quantity Like/Dislike
# 0   apple         5            l
# 1   mango         4            d
# 2  banana         6            l
# 3  orange         8            d

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np
lst=[['apple',5,'l'],['mango',4,'d'],['banana',np.nan,'l'],['orange',8,'d']]
df = pd.DataFrame(lst, columns=['fruits','quantity','Like/Dislike'])
df
# Out:
#    fruits  quantity Like/Dislike
# 0   apple       5.0            l
# 1   mango       4.0            d
# 2  banana       NaN            l
# 3  orange       8.0            d

# %%
#USING DICTIONARY

# %%
fruits ={
    'Fruits' : ['apple','mango','banana'],
    'Quantity' : [5,4,6]
}
df= pd.DataFrame(fruits)
df
# Out:
#    Fruits  Quantity
# 0   apple         5
# 1   mango         4
# 2  banana         6

# %%
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.Fruits
# Out:
# 0     apple
# 1     mango
# 2    banana
# Name: Fruits, dtype: object

# %%
df['Quantity']
# Out:
# 0    5
# 1    4
# 2    6
# Name: Quantity, dtype: int64

# %%
# ARITHMATIC OPERATIONS

# %%
df =pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df['A']+df['B']
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
df['C'] = df['A']+df['B']
df
# Out:
#    A  B  c  C  D
# 0  1  4  5  5  5
# 1  2  5  7  7  7
# 2  3  6  9  9  9

# %%
df['E'] = df['A']*df['B']
df
# Out:
#    A  B  c  C  D   E
# 0  1  4  5  5  5   4
# 1  2  5  7  7  7  10
# 2  3  6  9  9  9  18

# %%
#Insert and Delete

# %%
import pandas as pd
df =pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.insert (0,'new',['a','b','c'])
df
# Out:
#   new  A  B
# 0   a  1  4
# 1   b  2  5
# 2   c  3  6

# %%
df.insert(3,'B + C',df['A']+df['B'])
df
# Out:
#   new  A  B  B + C
# 0   a  1  4      5
# 1   b  2  5      7
# 2   c  3  6      9

# %%
# Delete

# %%
df
# Out:
#   new  A  B  B + C
# 0   a  1  4      5
# 1   b  2  5      7
# 2   c  3  6      9

# %%
d = df.copy()

# %%
del df['new']
df
# Out:
#    A  B  B + C
# 0  1  4      5
# 1  2  5      7
# 2  3  6      9

# %%
del df

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-15-1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
d
# Out:
#   new  A  B  B + C
# 0   a  1  4      5
# 1   b  2  5      7
# 2   c  3  6      9

# %%
# LOAD THE DATASET

# %%
df = pd.read_csv('petrol_consumption.csv')

df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# ...

# %%
#Basic EDA

# %%
df.shape
# Out:
# (48, 5)

# %%
df.columns
# Out:
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)', 'Petrol_Consumption'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Petrol_tax                    48 non-null     float64
#  1   Average_income                43 non-null     float64
#  2   Paved_Highways                43 non-null     float64
#  3   Population_Driver_licence(%)  47 non-null     float64
#  4   Petrol_Consumption            46 non-null     float64
# dtypes: float64(5)
# memory usage: 2.0 KB

# %%
df.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       43.000000       43.000000
# mean     7.668333     4261.627907     5126.232558
# std      0.950770      579.517781     2741.972637
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3773.500000     2946.500000
# 50%      7.500000     4300.000000     4725.000000
# 75%      8.125000     4543.000000     6749.500000
# max     10.000000     5342.000000    11868.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     47.000000           46.000000
# mean                       0.569532          582.608696
# std                        0.055788          110.465375
# min                        0.451000          344.000000
# 25%                        0.529500          524.000000
# 50%                        0.563000          572.500000
# 75%                        0.589500          634.250000
# max                        0.724000          968.000000

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0          3571.0          1976.0                         0.525
# 1         9.0          4092.0          1250.0                         0.572
# 2         9.0             NaN             NaN                         0.580
# 3         7.5          4870.0          2351.0                         0.529
# 4         8.0          4399.0           431.0                         0.544
#
#    Petrol_Consumption
# 0               541.0
# 1               524.0
# 2               561.0
# 3                 NaN
# 4               410.0

# %%
df.head(3)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0          3571.0          1976.0                         0.525
# 1         9.0          4092.0          1250.0                         0.572
# 2         9.0             NaN             NaN                         0.580
#
#    Petrol_Consumption
# 0               541.0
# 1               524.0
# 2               561.0

# %%
df.tail()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 43         7.0          3745.0          2611.0                         0.508
# 44         6.0          5215.0          2302.0                         0.672
# 45         9.0          4476.0          3942.0                         0.571
# 46         7.0          4296.0          4083.0                         0.623
# 47         7.0          5002.0          9794.0                         0.593
#
#     Petrol_Consumption
# 43               591.0
# 44               782.0
# 45               510.0
# 46               610.0
# 47               524.0

# %%
df.tail(2)
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 46         7.0          4296.0          4083.0                         0.623
# 47         7.0          5002.0          9794.0                         0.593
#
#     Petrol_Consumption
# 46               610.0
# 47               524.0

# %%
# INDEXING AND SLICING

# %%
df.head(8)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0          3571.0          1976.0                         0.525
# 1         9.0          4092.0          1250.0                         0.572
# 2         9.0             NaN             NaN                         0.580
# 3         7.5          4870.0          2351.0                         0.529
# 4         8.0          4399.0           431.0                         0.544
# 5        10.0          5342.0          1333.0                         0.571
# 6         8.0          5319.0         11868.0                         0.451
# 7         8.0          5126.0          2138.0                         0.553
#
#    Petrol_Consumption
# 0               541.0
# 1               524.0
# 2               561.0
# 3                 NaN
# 4               410.0
# 5               457.0
# 6               344.0
# 7               467.0

# %%
df.iloc[3]
# Out:
# Petrol_tax                         7.500
# Average_income                  4870.000
# Paved_Highways                  2351.000
# Population_Driver_licence(%)       0.529
# Petrol_Consumption                   NaN
# Name: 3, dtype: float64

# %%
df.iloc[0:48,0:5]
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# ...

# %%
df.iloc[:,:]
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# ...

# %%
df.iloc[0:5,0:3]
# Out:
#    Petrol_tax  Average_income  Paved_Highways
# 0         9.0          3571.0          1976.0
# 1         9.0          4092.0          1250.0
# 2         9.0             NaN             NaN
# 3         7.5          4870.0          2351.0
# 4         8.0          4399.0           431.0

# %%
df.iloc[4:11,0:5]
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 4          8.0          4399.0           431.0                         0.544
# 5         10.0          5342.0          1333.0                         0.571
# 6          8.0          5319.0         11868.0                         0.451
# 7          8.0          5126.0          2138.0                         0.553
# 8          8.0          4447.0          8577.0                         0.529
# 9          7.0          4512.0          8507.0                         0.552
# 10         8.0          4391.0          5939.0                         0.530
#
#     Petrol_Consumption
# 4                410.0
# 5                457.0
# 6                344.0
# 7                467.0
# 8                464.0
# 9                498.0
# 10               580.0

# %%
df.iloc[4:11,0:5:2]
# Out:
#     Petrol_tax  Paved_Highways  Petrol_Consumption
# 4          8.0           431.0               410.0
# 5         10.0          1333.0               457.0
# 6          8.0         11868.0               344.0
# 7          8.0          2138.0               467.0
# 8          8.0          8577.0               464.0
# 9          7.0          8507.0               498.0
# 10         8.0          5939.0               580.0

# %%
#LOC[]

# %%
# prompt: df.loc[4:11,['petrol_tax','Paved_Highways']] correct it

df.loc[4:11,]['Petrol_tax','Paved_Highways']
# Out:
#     Petrol_tax  Paved_Highways
# 4          8.0           431.0
# 5         10.0          1333.0
# 6          8.0         11868.0
# 7          8.0          2138.0
# 8          8.0          8577.0
# 9          7.0          8507.0
# 10         8.0          5939.0
# 11         7.5             NaN

# %%
df[['Petrol_tax','Paved_Highways']]
# Out:
#     Petrol_tax  Paved_Highways
# 0         9.00          1976.0
# 1         9.00          1250.0
# 2         9.00             NaN
# 3         7.50          2351.0
# 4         8.00           431.0
# 5        10.00          1333.0
# 6         8.00         11868.0
# 7         8.00          2138.0
# 8         8.00          8577.0
# 9         7.00          8507.0
# 10        8.00          5939.0
# 11        7.50             NaN
# 12        7.00          6930.0
# 13        7.00          6580.0
# 14        7.00          8159.0
# 15        7.00         10340.0
# 16        7.00             NaN
# 17        7.00          4725.0
# 18        7.00          5915.0
# 19        8.50          6010.0
# 20        7.00          7834.0
# 21        8.00           602.0
# 22        9.00          2449.0
# 23        9.00          4686.0
# 24        8.50          2619.0
# 25        9.00          4746.0
# 26        8.00          5399.0
# 27        7.50          9061.0
# 28        8.00          5975.0
# ...

# %%
df[['Petrol_tax','Paved_Highways']][0:6]
# Out:
#    Petrol_tax  Paved_Highways
# 0         9.0          1976.0
# 1         9.0          1250.0
# 2         9.0             NaN
# 3         7.5          2351.0
# 4         8.0           431.0
# 5        10.0          1333.0

# %%
df[['Petrol_tax','Paved_Highways']].index
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %%
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# ...

# %%
df[df['Petrol_tax']==9.0]
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0          9.0          3571.0          1976.0                         0.525
# 1          9.0          4092.0          1250.0                         0.572
# 2          9.0             NaN             NaN                         0.580
# 22         9.0          4897.0          2449.0                         0.511
# 23         9.0          4258.0          4686.0                         0.517
# 25         9.0          3721.0          4746.0                         0.544
# 29         9.0          3601.0             NaN                         0.493
# 45         9.0          4476.0          3942.0                         0.571
#
#     Petrol_Consumption
# 0                541.0
# 1                524.0
# 2                561.0
# 22               464.0
# 23               547.0
# 25               566.0
# 29               534.0
# 45               510.0

# %%
df[df['Petrol_tax']==9.0].index
# Out:
# Index([0, 1, 2, 22, 23, 25, 29, 45], dtype='int64')

# %%
# UNIQUE VALUE IDENTIFICATION
#unique()
#nunique()
#value_counts()

# %%
df.nunique()
# Out:
# Petrol_tax                       9
# Average_income                  42
# Paved_Highways                  42
# Population_Driver_licence(%)    38
# Petrol_Consumption              41
# dtype: int64

# %%
df['Petrol_tax'].nunique()
# Out:
# 9

# %%
df['Petrol_tax'].unique()
# Out:
# array([ 9.  ,  7.5 ,  8.  , 10.  ,  7.  ,  8.5 ,  6.58,  5.  ,  6.  ])

# %%
df['Petrol_tax'].value_counts()
# Out:
# Petrol_tax
# 7.00     19
# 8.00     10
# 9.00      8
# 7.50      4
# 8.50      3
# 10.00     1
# 6.58      1
# 5.00      1
# 6.00      1
# Name: count, dtype: int64

# %%
df['Petrol_tax'].mean()
# Out:
# np.float64(7.668333333333333)

# %%
df['Petrol_tax'].median()
# Out:
# 7.5

# %%
df['Petrol_tax'].mode()
# Out:
# 0    7.0
# Name: Petrol_tax, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

sns.distplot(df['Petrol_tax'], bins=30, color='blue', label=f"standard_deviation: {round(df['Petrol_tax'].skew(),5 )}", )
plt.legend()
plt.show()

# %%
# MISSSING
# fillna()
# dropna()

# %%
import pandas as pd
df = pd.read_csv('petrol_consumption.csv')
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# ...

# %%
df.isnull()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0        False           False           False                         False
# 1        False           False           False                         False
# 2        False            True            True                         False
# 3        False           False           False                         False
# 4        False           False           False                         False
# 5        False           False           False                         False
# 6        False           False           False                         False
# 7        False           False           False                         False
# 8        False           False           False                         False
# 9        False           False           False                         False
# 10       False           False           False                         False
# ...

# %%
df.isnull().any()
# Out:
# Petrol_tax                      False
# Average_income                   True
# Paved_Highways                   True
# Population_Driver_licence(%)     True
# Petrol_Consumption               True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  5
# Paved_Highways                  5
# Population_Driver_licence(%)    1
# Petrol_Consumption              2
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Petrol_tax                       0.000000
# Average_income                  10.416667
# Paved_Highways                  10.416667
# Population_Driver_licence(%)     2.083333
# Petrol_Consumption               4.166667
# dtype: float64

# %%
# fillna()

# %%
df.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  5
# Paved_Highways                  5
# Population_Driver_licence(%)    1
# Petrol_Consumption              2
# dtype: int64

# %%
df.fillna(55555)
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00         55555.0         55555.0                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# ...

# %%
df['Average_income'].mean()
# Out:
# np.float64(4261.627906976744)

# %%
df['Average_income'].median()
# Out:
# 4300.0

# %%
df['Average_income'].fillna(df['Average_income'].mean())
# Out:
# 0     3571.000000
# 1     4092.000000
# 2     4261.627907
# 3     4870.000000
# 4     4399.000000
# 5     5342.000000
# 6     5319.000000
# 7     5126.000000
# 8     4447.000000
# 9     4512.000000
# 10    4391.000000
# 11    5126.000000
# 12    4817.000000
# 13    4207.000000
# 14    4332.000000
# 15    4318.000000
# 16    4206.000000
# 17    3718.000000
# 18    4261.627907
# 19    4341.000000
# 20    4261.627907
# 21    4983.000000
# 22    4897.000000
# 23    4258.000000
# 24    4574.000000
# 25    3721.000000
# 26    3448.000000
# 27    3846.000000
# 28    4188.000000
# 29    3601.000000
# 30    3640.000000
# 31    3333.000000
# 32    3063.000000
# 33    3357.000000
# 34    4261.627907
# 35    3802.000000
# 36    4045.000000
# 37    3897.000000
# 38    3635.000000
# 39    4345.000000
# 40    4449.000000
# 41    4261.627907
# 42    4300.000000
# 43    3745.000000
# 44    5215.000000
# 45    4476.000000
# 46    4296.000000
# 47    5002.000000
# Name: Average_income, dtype: float64

# %%
df['Average_income'].fillna(df['Average_income'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-19-1711107259.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Average_income'].fillna(df['Average_income'].mean(),inplace=True)

# %%
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00     3571.000000          1976.0                         0.525
# 1         9.00     4092.000000          1250.0                         0.572
# 2         9.00     4261.627907             NaN                         0.580
# 3         7.50     4870.000000          2351.0                         0.529
# 4         8.00     4399.000000           431.0                         0.544
# 5        10.00     5342.000000          1333.0                         0.571
# 6         8.00     5319.000000         11868.0                         0.451
# 7         8.00     5126.000000          2138.0                         0.553
# 8         8.00     4447.000000          8577.0                         0.529
# 9         7.00     4512.000000          8507.0                         0.552
# 10        8.00     4391.000000          5939.0                         0.530
# ...

# %%
df.isna().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  5
# Population_Driver_licence(%)    1
# Petrol_Consumption              2
# dtype: int64

# %%
# dropna()

# %%
df.dropna()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00     3571.000000          1976.0                         0.525
# 1         9.00     4092.000000          1250.0                         0.572
# 4         8.00     4399.000000           431.0                         0.544
# 5        10.00     5342.000000          1333.0                         0.571
# 6         8.00     5319.000000         11868.0                         0.451
# 7         8.00     5126.000000          2138.0                         0.553
# 8         8.00     4447.000000          8577.0                         0.529
# 9         7.00     4512.000000          8507.0                         0.552
# 10        8.00     4391.000000          5939.0                         0.530
# 12        7.00     4817.000000          6930.0                         0.574
# 13        7.00     4207.000000          6580.0                         0.545
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (41, 5)

# %%
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00     3571.000000          1976.0                         0.525
# 1         9.00     4092.000000          1250.0                         0.572
# 4         8.00     4399.000000           431.0                         0.544
# 5        10.00     5342.000000          1333.0                         0.571
# 6         8.00     5319.000000         11868.0                         0.451
# 7         8.00     5126.000000          2138.0                         0.553
# 8         8.00     4447.000000          8577.0                         0.529
# 9         7.00     4512.000000          8507.0                         0.552
# 10        8.00     4391.000000          5939.0                         0.530
# 12        7.00     4817.000000          6930.0                         0.574
# 13        7.00     4207.000000          6580.0                         0.545
# ...

# %%
df.isna().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
# DUPLICATE DATA
# drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Petrol_tax, Average_income, Paved_Highways, Population_Driver_licence(%), Petrol_Consumption]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# DROP
# for specific column and row

# %%
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00     3571.000000          1976.0                         0.525
# 1         9.00     4092.000000          1250.0                         0.572
# 4         8.00     4399.000000           431.0                         0.544
# 5        10.00     5342.000000          1333.0                         0.571
# 6         8.00     5319.000000         11868.0                         0.451
# 7         8.00     5126.000000          2138.0                         0.553
# 8         8.00     4447.000000          8577.0                         0.529
# 9         7.00     4512.000000          8507.0                         0.552
# 10        8.00     4391.000000          5939.0                         0.530
# 12        7.00     4817.000000          6930.0                         0.574
# 13        7.00     4207.000000          6580.0                         0.545
# ...

# %%
df.drop(columns=['Petrol_tax'],axis=1,inplace=True)

# %%
df
# Out:
#     Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0      3571.000000          1976.0                         0.525
# 1      4092.000000          1250.0                         0.572
# 4      4399.000000           431.0                         0.544
# 5      5342.000000          1333.0                         0.571
# 6      5319.000000         11868.0                         0.451
# 7      5126.000000          2138.0                         0.553
# 8      4447.000000          8577.0                         0.529
# 9      4512.000000          8507.0                         0.552
# 10     4391.000000          5939.0                         0.530
# 12     4817.000000          6930.0                         0.574
# 13     4207.000000          6580.0                         0.545
# 15     4318.000000         10340.0                         0.586
# 17     3718.000000          4725.0                         0.540
# ...

# %%
df.drop(index = [0,4,7,9],axis=0,inplace=True)

# %%
df
# Out:
#     Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 1      4092.000000          1250.0                         0.572
# 5      5342.000000          1333.0                         0.571
# 6      5319.000000         11868.0                         0.451
# 8      4447.000000          8577.0                         0.529
# 10     4391.000000          5939.0                         0.530
# 12     4817.000000          6930.0                         0.574
# 13     4207.000000          6580.0                         0.545
# 15     4318.000000         10340.0                         0.586
# 17     3718.000000          4725.0                         0.540
# 18     4261.627907          5915.0                         0.724
# 19     4341.000000          6010.0                         0.677
# 20     4261.627907          7834.0                         0.663
# 21     4983.000000           602.0                         0.602
# ...

# %%
df.shape
# Out:
# (37, 4)

# %%
# CONCAT AND MERGE

# %%
df1= pd.DataFrame({'A':[1,2,3,4,5], 'B':[6,7,8,9,10]})
df2= pd.DataFrame({'A':[11,12,13,14,15], 'B':[16,17,18,19,20]})
df1
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
df2
# Out:
#     A   B
# 0  11  16
# 1  12  17
# 2  13  18
# 3  14  19
# 4  15  20

# %%
pd.concat([df1,df2])
# Out:
#     A   B
# 0   1   6
# 1   2   7
# 2   3   8
# 3   4   9
# 4   5  10
# 0  11  16
# 1  12  17
# 2  13  18
# 3  14  19
# 4  15  20

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#     A   B
# 0   1   6
# 1   2   7
# 2   3   8
# 3   4   9
# 4   5  10
# 5  11  16
# 6  12  17
# 7  13  18
# 8  14  19
# 9  15  20

# %%
# prompt: pd.concat([df1,df2],axis=1,ColumnName=['a','b','c','d']) correct it

pd.concat([df1,df2],axis=1)
# Out:
#    A   B   A   B
# 0  1   6  11  16
# 1  2   7  12  17
# 2  3   8  13  18
# 3  4   9  14  19
# 4  5  10  15  20

# %%
# MERGE

# %%
df1= pd.DataFrame({'A':[1,2,3,4,5], 'B':[6,7,8,9,10]})
df2= pd.DataFrame({'A':[1,2,3,4,5], 'D':[16,17,18,19,20]})

# %%
df1.merge(df2)
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
df2.merge(df1)
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
# GROUP BY FUNCTION
# GroupBy()

# %%
import pandas as pd
data = pd.read_csv('emp_data.csv')
data
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %%
data.nunique()
# Out:
# Emp_id    100
# Name      100
# City        4
# Salary    100
# dtype: int64

# %%
data['City'].unique()
# Out:
# array(['Noida', 'Banglore', 'Pune', 'Gurgaon'], dtype=object)

# %%
data.value_counts()
# Out:
# Emp_id  Name     City      Salary
# 1       Emp_1    Noida     76252     1
# 2       Emp_2    Banglore  60315     1
# 3       Emp_3    Noida     73672     1
# 4       Emp_4    Pune      46501     1
# 5       Emp_5    Banglore  68611     1
#                                     ..
# 96      Emp_96   Banglore  60006     1
# 97      Emp_97   Noida     60635     1
# 98      Emp_98   Gurgaon   51311     1
# 99      Emp_99   Pune      89409     1
# 100     Emp_100  Gurgaon   92971     1
# Name: count, Length: 100, dtype: int64

# %%
data["City"].value_counts()
# Out:
# City
# Gurgaon     35
# Noida       30
# Banglore    18
# Pune        17
# Name: count, dtype: int64

# %%
data.groupby("City")

# %%
# prompt: noida = data.groupby("City").get_group("noida")
# noida correct it

noida = data.groupby("City").get_group("Noida")
noida
# Out:
#     Emp_id    Name   City  Salary
# 0        1   Emp_1  Noida   76252
# 2        3   Emp_3  Noida   73672
# 9       10  Emp_10  Noida   66920
# 11      12  Emp_12  Noida   68936
# 13      14  Emp_14  Noida   92541
# 18      19  Emp_19  Noida   43908
# 21      22  Emp_22  Noida   71302
# 33      34  Emp_34  Noida   96846
# 36      37  Emp_37  Noida   98538
# 42      43  Emp_43  Noida   88075
# 44      45  Emp_45  Noida   58527
# 46      47  Emp_47  Noida   48400
# 47      48  Emp_48  Noida   46042
# 49      50  Emp_50  Noida   52329
# 51      52  Emp_52  Noida   71335
# 53      54  Emp_54  Noida   52683
# 59      60  Emp_60  Noida   45004
# 61      62  Emp_62  Noida   86583
# 62      63  Emp_63  Noida   90083
# 64      65  Emp_65  Noida   45905
# 66      67  Emp_67  Noida   48382
# 67      68  Emp_68  Noida   77912
# 74      75  Emp_75  Noida   86643
# 77      78  Emp_78  Noida   93787
# 82      83  Emp_83  Noida   74060
# 84      85  Emp_85  Noida   51840
# ...

# %%
noida
# Out:
#     Emp_id    Name   City  Salary
# 0        1   Emp_1  Noida   76252
# 2        3   Emp_3  Noida   73672
# 9       10  Emp_10  Noida   66920
# 11      12  Emp_12  Noida   68936
# 13      14  Emp_14  Noida   92541
# 18      19  Emp_19  Noida   43908
# 21      22  Emp_22  Noida   71302
# 33      34  Emp_34  Noida   96846
# 36      37  Emp_37  Noida   98538
# 42      43  Emp_43  Noida   88075
# 44      45  Emp_45  Noida   58527
# 46      47  Emp_47  Noida   48400
# 47      48  Emp_48  Noida   46042
# 49      50  Emp_50  Noida   52329
# 51      52  Emp_52  Noida   71335
# 53      54  Emp_54  Noida   52683
# 59      60  Emp_60  Noida   45004
# 61      62  Emp_62  Noida   86583
# 62      63  Emp_63  Noida   90083
# 64      65  Emp_65  Noida   45905
# 66      67  Emp_67  Noida   48382
# 67      68  Emp_68  Noida   77912
# 74      75  Emp_75  Noida   86643
# 77      78  Emp_78  Noida   93787
# 82      83  Emp_83  Noida   74060
# 84      85  Emp_85  Noida   51840
# ...

# %%
noida.shape
# Out:
# (30, 4)

# %%
noida['Salary'].min()
# Out:
# 43908

# %%
noida['Salary'].max()
# Out:
# 98538

# %%
noida[noida['Salary']==43908]
# Out:
#     Emp_id    Name   City  Salary
# 18      19  Emp_19  Noida   43908

# %%
noida[noida['Salary']==98538]
# Out:
#     Emp_id    Name   City  Salary
# 36      37  Emp_37  Noida   98538

# %%
noida['Salary'].mean()
# Out:
# np.float64(70728.9)

# %%
noida[noida['Salary']< 70728]
# Out:
#     Emp_id    Name   City  Salary
# 9       10  Emp_10  Noida   66920
# 11      12  Emp_12  Noida   68936
# 18      19  Emp_19  Noida   43908
# 44      45  Emp_45  Noida   58527
# 46      47  Emp_47  Noida   48400
# 47      48  Emp_48  Noida   46042
# 49      50  Emp_50  Noida   52329
# 53      54  Emp_54  Noida   52683
# 59      60  Emp_60  Noida   45004
# 64      65  Emp_65  Noida   45905
# 66      67  Emp_67  Noida   48382
# 84      85  Emp_85  Noida   51840
# 96      97  Emp_97  Noida   60635

# %%
len(noida[noida['Salary']< 70728])
# Out:
# 13

# %%
noida[noida['Salary']< 70728]['Salary']
# Out:
# 9     66920
# 11    68936
# 18    43908
# 44    58527
# 46    48400
# 47    46042
# 49    52329
# 53    52683
# 59    45004
# 64    45905
# 66    48382
# 84    51840
# 96    60635
# Name: Salary, dtype: int64

# %%
# prompt: noida[noida['Salary']< 70728]['Salary','Name'] correct it

noida[noida['Salary'] < 70728][['Salary', 'Name']]
# Out:
#     Salary    Name
# 9    66920  Emp_10
# 11   68936  Emp_12
# 18   43908  Emp_19
# 44   58527  Emp_45
# 46   48400  Emp_47
# 47   46042  Emp_48
# 49   52329  Emp_50
# 53   52683  Emp_54
# 59   45004  Emp_60
# 64   45905  Emp_65
# 66   48382  Emp_67
# 84   51840  Emp_85
# 96   60635  Emp_97

# %%
noida[noida['Salary'] < 70728][['Salary', 'Name']].values
# Out:
# array([[66920, 'Emp_10'],
#        [68936, 'Emp_12'],
#        [43908, 'Emp_19'],
#        [58527, 'Emp_45'],
#        [48400, 'Emp_47'],
#        [46042, 'Emp_48'],
#        [52329, 'Emp_50'],
#        [52683, 'Emp_54'],
#        [45004, 'Emp_60'],
#        [45905, 'Emp_65'],
#        [48382, 'Emp_67'],
#        [51840, 'Emp_85'],
#        [60635, 'Emp_97']], dtype=object)

# %%
list(noida[noida['Salary'] < 70728][['Salary', 'Name']].values)
# Out:
# [array([66920, 'Emp_10'], dtype=object),
#  array([68936, 'Emp_12'], dtype=object),
#  array([43908, 'Emp_19'], dtype=object),
#  array([58527, 'Emp_45'], dtype=object),
#  array([48400, 'Emp_47'], dtype=object),
#  array([46042, 'Emp_48'], dtype=object),
#  array([52329, 'Emp_50'], dtype=object),
#  array([52683, 'Emp_54'], dtype=object),
#  array([45004, 'Emp_60'], dtype=object),
#  array([45905, 'Emp_65'], dtype=object),
#  array([48382, 'Emp_67'], dtype=object),
#  array([51840, 'Emp_85'], dtype=object),
#  array([60635, 'Emp_97'], dtype=object)]

# %%
noida[noida['Salary'] < 70728][['Salary', 'Name']].index
# Out:
# Index([9, 11, 18, 44, 46, 47, 49, 53, 59, 64, 66, 84, 96], dtype='int64')

# %%
pune = data.groupby("City").get_group("Pune")
pune
# Out:
#     Emp_id    Name  City  Salary
# 3        4   Emp_4  Pune   46501
# 15      16  Emp_16  Pune   82394
# 16      17  Emp_17  Pune   75880
# 31      32  Emp_32  Pune   70196
# 32      33  Emp_33  Pune   66026
# 39      40  Emp_40  Pune   48539
# 43      44  Emp_44  Pune   55560
# 48      49  Emp_49  Pune   64984
# 72      73  Emp_73  Pune   47144
# 73      74  Emp_74  Pune   52826
# 75      76  Emp_76  Pune   46014
# 78      79  Emp_79  Pune   92844
# 83      84  Emp_84  Pune   45896
# 90      91  Emp_91  Pune   68734
# 91      92  Emp_92  Pune   52235
# 92      93  Emp_93  Pune   47001
# 98      99  Emp_99  Pune   89409

# %%
pune.shape
# Out:
# (17, 4)

# %%
pune['City'].value_counts()
# Out:
# City
# Pune    17
# Name: count, dtype: int64

# %%
pune['Salary'].min()
# Out:
# 45896

# %%
pune[pune['Salary']==45896]
# Out:
#     Emp_id    Name  City  Salary
# 83      84  Emp_84  Pune   45896

# %%
pune[pune['Salary']>45896]
# Out:
#     Emp_id    Name  City  Salary
# 3        4   Emp_4  Pune   46501
# 15      16  Emp_16  Pune   82394
# 16      17  Emp_17  Pune   75880
# 31      32  Emp_32  Pune   70196
# 32      33  Emp_33  Pune   66026
# 39      40  Emp_40  Pune   48539
# 43      44  Emp_44  Pune   55560
# 48      49  Emp_49  Pune   64984
# 72      73  Emp_73  Pune   47144
# 73      74  Emp_74  Pune   52826
# 75      76  Emp_76  Pune   46014
# 78      79  Emp_79  Pune   92844
# 90      91  Emp_91  Pune   68734
# 91      92  Emp_92  Pune   52235
# 92      93  Emp_93  Pune   47001
# 98      99  Emp_99  Pune   89409

# %%
# SET INDEX AND RESET INDEX
# Set_index()  and   Reset_index()

# %%
data
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %%
data.set_index('Emp_id')
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
data.set_index('Emp_id',inplace = True)

# %%
data
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
data.reset_index()
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %%
data
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
# Sort_values()

# %%
data
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
data.sort_values('Salary')
# Out:
#           Name      City  Salary
# Emp_id
# 89      Emp_89   Gurgaon   43883
# 19      Emp_19     Noida   43908
# 6        Emp_6  Banglore   44646
# 26      Emp_26  Banglore   44710
# 60      Emp_60     Noida   45004
# ...        ...       ...     ...
# 78      Emp_78     Noida   93787
# 7        Emp_7  Banglore   95408
# 36      Emp_36   Gurgaon   95851
# 34      Emp_34     Noida   96846
# 37      Emp_37     Noida   98538
#
# [100 rows x 3 columns]

# %%
data.sort_values('Salary',ascending=False)
# Out:
#           Name      City  Salary
# Emp_id
# 37      Emp_37     Noida   98538
# 34      Emp_34     Noida   96846
# 36      Emp_36   Gurgaon   95851
# 7        Emp_7  Banglore   95408
# 78      Emp_78     Noida   93787
# ...        ...       ...     ...
# 60      Emp_60     Noida   45004
# 26      Emp_26  Banglore   44710
# 6        Emp_6  Banglore   44646
# 19      Emp_19     Noida   43908
# 89      Emp_89   Gurgaon   43883
#
# [100 rows x 3 columns]

# %%
# map() and apply()

# %%
data
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
# map()

# %%
data['City'].value_counts()
# Out:
# City
# Gurgaon     35
# Noida       30
# Banglore    18
# Pune        17
# Name: count, dtype: int64

# %%
data['City'].map({'Gurgaon':1,'Noida':2,'Banglore':3,'Pune':4})
# Out:
# Emp_id
# 1      2
# 2      3
# 3      2
# 4      4
# 5      3
#       ..
# 96     3
# 97     2
# 98     1
# 99     4
# 100    1
# Name: City, Length: 100, dtype: int64

# %%
data
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
data['City'] = data['City'].map({'Gurgaon':1,'Noida':2,'Banglore':3,'Pune':4})
data
# Out:
#            Name  City  Salary
# Emp_id
# 1         Emp_1     2   76252
# 2         Emp_2     3   60315
# 3         Emp_3     2   73672
# 4         Emp_4     4   46501
# 5         Emp_5     3   68611
# ...         ...   ...     ...
# 96       Emp_96     3   60006
# 97       Emp_97     2   60635
# 98       Emp_98     1   51311
# 99       Emp_99     4   89409
# 100     Emp_100     1   92971
#
# [100 rows x 3 columns]

# %%
# apply()

# %%
data
# Out:
#            Name  City  Salary
# Emp_id
# 1         Emp_1     2   76252
# 2         Emp_2     3   60315
# 3         Emp_3     2   73672
# 4         Emp_4     4   46501
# 5         Emp_5     3   68611
# ...         ...   ...     ...
# 96       Emp_96     3   60006
# 97       Emp_97     2   60635
# 98       Emp_98     1   51311
# 99       Emp_99     4   89409
# 100     Emp_100     1   92971
#
# [100 rows x 3 columns]

# %%
data['Name'].apply(lambda x: x.replace('_',"-"))
# Out:
# Emp_id
# 1        Emp-1
# 2        Emp-2
# 3        Emp-3
# 4        Emp-4
# 5        Emp-5
#         ...
# 96      Emp-96
# 97      Emp-97
# 98      Emp-98
# 99      Emp-99
# 100    Emp-100
# Name: Name, Length: 100, dtype: object

# %%
data['Updated_Name']= data['Name'].apply(lambda x: x.replace('_',"-"))

# %%
data
# Out:
#            Name  City  Salary Updated_Name
# Emp_id
# 1         Emp_1     2   76252        Emp-1
# 2         Emp_2     3   60315        Emp-2
# 3         Emp_3     2   73672        Emp-3
# 4         Emp_4     4   46501        Emp-4
# 5         Emp_5     3   68611        Emp-5
# ...         ...   ...     ...          ...
# 96       Emp_96     3   60006       Emp-96
# 97       Emp_97     2   60635       Emp-97
# 98       Emp_98     1   51311       Emp-98
# 99       Emp_99     4   89409       Emp-99
# 100     Emp_100     1   92971      Emp-100
#
# [100 rows x 4 columns]

# %%
def INR_to_Dollar(salary):
  dollar = []

  for i in salary:
    d=i/85.50
    dollar.append(f'{round(d,2)}USD')
  return dollar

# %%
INR_to_Dollar(data['Salary'])
# Out:
# ['891.84USD',
#  '705.44USD',
#  '861.66USD',
#  '543.87USD',
#  '802.47USD',
#  '522.18USD',
#  '1115.88USD',
#  '890.89USD',
#  '1040.92USD',
#  '782.69USD',
#  '592.02USD',
#  '806.27USD',
#  '762.77USD',
#  '1082.35USD',
#  '643.08USD',
#  '963.67USD',
#  '887.49USD',
#  '731.63USD',
#  '513.54USD',
#  '1034.62USD',
#  '795.24USD',
#  '833.94USD',
#  '831.06USD',
#  '883.31USD',
#  '614.32USD',
#  '522.92USD',
#  '956.35USD',
#  '595.25USD',
#  '1082.14USD',
#  '1052.25USD',
#  '722.08USD',
#  '821.01USD',
#  '772.23USD',
#  '1132.7USD',
#  '820.32USD',
#  '1121.06USD',
#  '1152.49USD',
#  '585.65USD',
#  '649.13USD',
#  '567.71USD',
#  '914.88USD',
#  '931.73USD',
#  '1030.12USD',
#  '649.82USD',
#  '684.53USD',
#  '694.84USD',
#  '566.08USD',
#  '538.5USD',
#  '760.05USD',
#  '612.04USD',
#  '581.61USD',
#  '834.33USD',
#  '663.09USD',
#  '616.18USD',
#  '818.22USD',
#  '570.82USD',
#  '912.16USD',
#  '1057.6USD',
#  '1041.61USD',
#  '526.36USD',
#  '1009.52USD',
# ...

# %%
data['Salary_IN_$'] = INR_to_Dollar(data['Salary'])

# %%
data
# Out:
#            Name  City  Salary Updated_Name Salary_IN_$
# Emp_id
# 1         Emp_1     2   76252        Emp-1   891.84USD
# 2         Emp_2     3   60315        Emp-2   705.44USD
# 3         Emp_3     2   73672        Emp-3   861.66USD
# 4         Emp_4     4   46501        Emp-4   543.87USD
# 5         Emp_5     3   68611        Emp-5   802.47USD
# ...         ...   ...     ...          ...         ...
# 96       Emp_96     3   60006       Emp-96   701.82USD
# 97       Emp_97     2   60635       Emp-97   709.18USD
# 98       Emp_98     1   51311       Emp-98   600.13USD
# 99       Emp_99     4   89409       Emp-99  1045.72USD
# 100     Emp_100     1   92971      Emp-100  1087.38USD
#
# [100 rows x 5 columns]

# %%
data.to_dict()
# Out:
# {'Name': {1: 'Emp_1',
#   2: 'Emp_2',
#   3: 'Emp_3',
#   4: 'Emp_4',
#   5: 'Emp_5',
#   6: 'Emp_6',
#   7: 'Emp_7',
#   8: 'Emp_8',
#   9: 'Emp_9',
#   10: 'Emp_10',
#   11: 'Emp_11',
#   12: 'Emp_12',
#   13: 'Emp_13',
#   14: 'Emp_14',
#   15: 'Emp_15',
#   16: 'Emp_16',
#   17: 'Emp_17',
#   18: 'Emp_18',
#   19: 'Emp_19',
#   20: 'Emp_20',
#   21: 'Emp_21',
#   22: 'Emp_22',
#   23: 'Emp_23',
#   24: 'Emp_24',
#   25: 'Emp_25',
#   26: 'Emp_26',
#   27: 'Emp_27',
#   28: 'Emp_28',
#   29: 'Emp_29',
#   30: 'Emp_30',
#   31: 'Emp_31',
#   32: 'Emp_32',
#   33: 'Emp_33',
#   34: 'Emp_34',
#   35: 'Emp_35',
#   36: 'Emp_36',
#   37: 'Emp_37',
#   38: 'Emp_38',
#   39: 'Emp_39',
#   40: 'Emp_40',
#   41: 'Emp_41',
#   42: 'Emp_42',
#   43: 'Emp_43',
#   44: 'Emp_44',
#   45: 'Emp_45',
#   46: 'Emp_46',
#   47: 'Emp_47',
#   48: 'Emp_48',
#   49: 'Emp_49',
#   50: 'Emp_50',
#   51: 'Emp_51',
#   52: 'Emp_52',
#   53: 'Emp_53',
#   54: 'Emp_54',
#   55: 'Emp_55',
#   56: 'Emp_56',
# ...

# %%
data.to_json()
# Out:
# '{"Name":{"1":"Emp_1","2":"Emp_2","3":"Emp_3","4":"Emp_4","5":"Emp_5","6":"Emp_6","7":"Emp_7","8":"Emp_8","9":"Emp_9","10":"Emp_10","11":"Emp_11","12":"Emp_12","13":"Emp_13","14":"Emp_14","15":"Emp_15","16":"Emp_16","17":"Emp_17","18":"Emp_18","19":"Emp_19","20":"Emp_20","21":"Emp_21","22":"Emp_22","23":"Emp_23","24":"Emp_24","25":"Emp_25","26":"Emp_26","27":"Emp_27","28":"Emp_28","29":"Emp_29","30":"Emp_30","31":"Emp_31","32":"Emp_32","33":"Emp_33","34":"Emp_34","35":"Emp_35","36":"Emp_36","37":"Emp_37","38":"Emp_38","39":"Emp_39","40":"Emp_40","41":"Emp_41","42":"Emp_42","43":"Emp_43","44":"Emp_44","45":"Emp_45","46":"Emp_46","47":"Emp_47","48":"Emp_48","49":"Emp_49","50":"Emp_50","51":"Emp_51","52":"Emp_52","53":"Emp_53","54":"Emp_54","55":"Emp_55","56":"Emp_56","57":"Emp_57","58":"Emp_58","59":"Emp_59","60":"Emp_60","61":"Emp_61","62":"Emp_62","63":"Emp_63","64":"Emp_64","65":"Emp_65","66":"Emp_66","67":"Emp_67","68":"Emp_68","69":"Emp_69","70":"Emp_70","71":"Emp_71","72":"Emp_72
# ...
